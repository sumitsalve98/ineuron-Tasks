# %% [markdown]
# # pandas bootcamp day 3 task

# %% [raw]
# #Task 1 - Fitbit Dataset
#
# 1. Read this dataset in pandas , mysql and mongodb
# 2. while creting a table in mysql dont use manual approach to create it  ,always use a automation to create a table in mysql
#  ## hint - use csvkit library to automate this task and to load a data in bulk in you mysql
# 3. convert all the dates avaible in dataset to timestamp format in pandas and in sql you to convert it in date format
# 4 . Find out in this data that how many unique id's we have
# 5 . which id is one of the active id that you have in whole dataset
# 6 . how many of them have not logged there activity find out in terms of number of ids
# 7 . Find out who is the laziest person id that we have in dataset
# 8 . Explore over an internet that how much calories burn is required for a healthy person and find out how many healthy person we have in our dataset
# 9. how many person are not a regular person with respect to activity try to find out those
# 10 . who is the thired most active person in this dataset find out those in pandas and in sql both .
# 11 . who is the 5th most laziest person avilable in dataset find it out
# 12 . what is a totla acumulative calories burn for a person find out

# %% [raw]
# #task 2 - Superstore_USA
# 1 . load this data in sql and in pandas with a relation in sql
# 2 . while loading this data you dont have to create a table manually you can use any automated approach to create a table and load a data in bulk in table
# 3 . Find out how return that we ahve recived and with a product id
# 4 . try  to join order and return data both in sql and pandas
# 5 . Try to find out how many unique customer that we have
# 6 . try to find out in how many regions we are selling a product and who is a manager for a respective region
# 7 . find out how many different differnet shipement mode that we have and what is a percentage usablity of all the shipment mode with respect to dataset
# 8 . Create a new coulmn and try to find our a diffrence between order date and shipment date
# 9 . base on question number 8 find out for which order id we have shipment duration more than 10 days
# 10 . Try to find out a list of a returned order which sihpment duration was more then 15 days and find out that region manager as well
# 11 . Gorup by region and find out which region is more profitable
# 12 . Try to find out overalll in which country we are giving more didscount
# 13 . Give me a list of unique postal code
# 14 . which customer segement is more profitalble find it out .
# 15 . try to find out the 10th most loss making product catagory .
# 16 . Try to find out 10 top  product with highest margins
#
# submit your git link for the same
#
# you have to submit this task by next Friday 5th 11PM IST  to respective mail id
# sudhanshu@ineuron.ai , sunny.savita@ineuron.ai

# %% [markdown]
# # TASK 1

# %% [markdown]
# # 1. Read this dataset in pandas , mysql and mongodb

# %% [markdown]
# ## Reading in pandas

# %%
import pandas as pd

# %%
df = pd.read_csv(r"D:\ineuron resourses\panda task 3\FitBit data.csv")
df
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391     4/8/2016       23014      20.389999        20.389999
# 453  8877689391     4/9/2016       16470       8.070000         8.070000
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
# 455  8877689391    4/11/2016       10622       8.060000         8.060000
# 456  8877689391    4/12/2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                         0.0                2.57                      0.46
# 1                         0.0                6.92                      0.73
# 2                         0.0                4.66                      0.16
# 3                         0.0                3.19                      0.79
# 4                         0.0                2.16                      1.09
# ..                        ...                 ...                       ...
# 452                       0.0               11.10                      0.63
# 453                       0.0                0.00                      0.02
# 454                       0.0               21.92                      1.12
# 455                       0.0                1.47                      0.15
# 456                       0.0                0.00                      0.00
#
#      LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                   4.07                     0.00                 33
# 1                   3.91                     0.00                 89
# 2                   3.71                     0.00                 56
# 3                   4.95                     0.00                 39
# 4                   4.61                     0.00                 28
# ..                   ...                      ...                ...
# 452                 8.62                     0.00                 70
# 453                 8.02                     0.00                 90
# 454                 4.46                     0.00                128
# 455                 6.37                     0.01                 18
# 456                 1.78                     0.00                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 0                     12                   205               804      1819
# 1                     17                   274               588      2154
# 2                      5                   268               605      1944
# 3                     20                   224              1080      1932
# 4                     28                   243               763      1886
# ..                   ...                   ...               ...       ...
# 452                   29                   359               982      4196
# 453                    9                   289              1052      3841
# 454                   46                   211              1055      4526
# 455                    7                   225              1190      2820
# 456                    0                    58               531       938
#
# [457 rows x 15 columns]

# %% [markdown]
# ## loading in sql

# %%
import mysql.connector as connection
mydb = connection.connect(host = "localhost",
                           user ="root",
                           passwd = "45515771",
                           use_pure = "True")
cursor = mydb.cursor()

query = "create database pandastask3"

cursor.execute(query)

# %%
df = pd.read_csv(r"D:\ineuron resourses\panda task 3\FitBit data.csv")

# %%
from sqlalchemy import create_engine

# %%
#mysql+mysqlconnector://user:passwd@host:port/dbname
engine = create_engine('mysql+mysqlconnector://root:45515771@localhost:3306/pandastask3')

# %%
df.to_sql(name= "FitBit_data" , con = engine , if_exists= "append" , index = False)
# Out:
# C:\Users\sumit\anaconda3\lib\site-packages\pandas\io\sql.py:1685: UserWarning: The provided table name 'FitBit_data' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## loading in mongodb

# %%
import pandas as pd
import pymongo
import json

# %%
client = pymongo.MongoClient("mongodb+srv://sumitsalve:325978456566324@cluster0.4dylrww.mongodb.net/?retryWrites=true&w=majority")

# %%
mdb = client["pandas_task3"]

# %%
mdb.drop_collection('fitbit_data')
# Out:
# {'ok': 0.0,
#  'errmsg': 'ns not found',
#  'code': 26,
#  'codeName': 'NamespaceNotFound',
#  '$clusterTime': {'clusterTime': Timestamp(1662025810, 4),
#   'signature': {'hash': b'\xa4\xaaq\xfc\x12Q6\xf7Q\x87q\xd30\xd6`\x9a\x16\xa2\xe9G',
#    'keyId': 7088037605794643973}},
#  'operationTime': Timestamp(1662025810, 4)}

# %%
coll = mdb["fitbit_data"]

# %%
df = pd.read_csv(r"D:\ineuron resourses\panda task 3\FitBit data.csv")

# %%
#coverting DataFrame into dictionary
data = df.to_dict(orient = "records")
data
# Out:
# [{'Id': 1503960366,
#   'ActivityDate': '3/25/2016',
#   'TotalSteps': 11004,
#   'TotalDistance': 7.1100001335144,
#   'TrackerDistance': 7.1100001335144,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 2.5699999332428,
#   'ModeratelyActiveDistance': 0.46000000834465,
#   'LightActiveDistance': 4.07000017166138,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 33,
#   'FairlyActiveMinutes': 12,
#   'LightlyActiveMinutes': 205,
#   'SedentaryMinutes': 804,
#   'Calories': 1819},
#  {'Id': 1503960366,
#   'ActivityDate': '3/26/2016',
#   'TotalSteps': 17609,
#   'TotalDistance': 11.5500001907349,
#   'TrackerDistance': 11.5500001907349,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 6.92000007629395,
#   'ModeratelyActiveDistance': 0.730000019073486,
#   'LightActiveDistance': 3.91000008583069,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 89,
#   'FairlyActiveMinutes': 17,
#   'LightlyActiveMinutes': 274,
#   'SedentaryMinutes': 588,
#   'Calories': 2154},
#  {'Id': 1503960366,
#   'ActivityDate': '3/27/2016',
#   'TotalSteps': 12736,
#   'TotalDistance': 8.52999973297119,
#   'TrackerDistance': 8.52999973297119,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 4.65999984741211,
#   'ModeratelyActiveDistance': 0.159999996423721,
#   'LightActiveDistance': 3.71000003814697,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 56,
#   'FairlyActiveMinutes': 5,
#   'LightlyActiveMinutes': 268,
#   'SedentaryMinutes': 605,
#   'Calories': 1944},
#  {'Id': 1503960366,
#   'ActivityDate': '3/28/2016',
#   'TotalSteps': 13231,
#   'TotalDistance': 8.93000030517578,
#   'TrackerDistance': 8.93000030517578,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 3.19000005722046,
#   'ModeratelyActiveDistance': 0.790000021457672,
#   'LightActiveDistance': 4.94999980926514,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 39,
#   'FairlyActiveMinutes': 20,
#   'LightlyActiveMinutes': 224,
#   'SedentaryMinutes': 1080,
#   'Calories': 1932},
#  {'Id': 1503960366,
#   'ActivityDate': '3/29/2016',
#   'TotalSteps': 12041,
#   'TotalDistance': 7.84999990463257,
#   'TrackerDistance': 7.84999990463257,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 2.16000008583069,
#   'ModeratelyActiveDistance': 1.0900000333786,
#   'LightActiveDistance': 4.6100001335144,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 28,
#   'FairlyActiveMinutes': 28,
#   'LightlyActiveMinutes': 243,
#   'SedentaryMinutes': 763,
#   'Calories': 1886},
#  {'Id': 1503960366,
#   'ActivityDate': '3/30/2016',
#   'TotalSteps': 10970,
#   'TotalDistance': 7.15999984741211,
#   'TrackerDistance': 7.15999984741211,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 2.35999989509583,
#   'ModeratelyActiveDistance': 0.509999990463257,
#   'LightActiveDistance': 4.28999996185303,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 30,
#   'FairlyActiveMinutes': 13,
#   'LightlyActiveMinutes': 223,
#   'SedentaryMinutes': 1174,
#   'Calories': 1820},
#  {'Id': 1503960366,
#   'ActivityDate': '3/31/2016',
#   'TotalSteps': 12256,
#   'TotalDistance': 7.8600001335144,
#   'TrackerDistance': 7.8600001335144,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 2.28999996185303,
#   'ModeratelyActiveDistance': 0.490000009536743,
#   'LightActiveDistance': 5.03999996185303,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 33,
#   'FairlyActiveMinutes': 12,
#   'LightlyActiveMinutes': 239,
#   'SedentaryMinutes': 820,
#   'Calories': 1889},
#  {'Id': 1503960366,
#   'ActivityDate': '4/1/2016',
#   'TotalSteps': 12262,
#   'TotalDistance': 7.86999988555908,
#   'TrackerDistance': 7.86999988555908,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 3.3199999332428,
#   'ModeratelyActiveDistance': 0.829999983310699,
#   'LightActiveDistance': 3.64000010490417,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 47,
#   'FairlyActiveMinutes': 21,
#   'LightlyActiveMinutes': 200,
#   'SedentaryMinutes': 866,
#   'Calories': 1868},
#  {'Id': 1503960366,
#   'ActivityDate': '4/2/2016',
#   'TotalSteps': 11248,
#   'TotalDistance': 7.25,
#   'TrackerDistance': 7.25,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 3.0,
#   'ModeratelyActiveDistance': 0.449999988079071,
#   'LightActiveDistance': 3.74000000953674,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 40,
#   'FairlyActiveMinutes': 11,
#   'LightlyActiveMinutes': 244,
#   'SedentaryMinutes': 636,
#   'Calories': 1843},
#  {'Id': 1503960366,
#   'ActivityDate': '4/3/2016',
#   'TotalSteps': 10016,
#   'TotalDistance': 6.36999988555908,
#   'TrackerDistance': 6.36999988555908,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.910000026226044,
#   'ModeratelyActiveDistance': 1.27999997138977,
#   'LightActiveDistance': 4.17999982833862,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 15,
#   'FairlyActiveMinutes': 30,
#   'LightlyActiveMinutes': 314,
#   'SedentaryMinutes': 655,
#   'Calories': 1850},
#  {'Id': 1503960366,
#   'ActivityDate': '4/4/2016',
#   'TotalSteps': 14557,
#   'TotalDistance': 9.80000019073486,
#   'TrackerDistance': 9.80000019073486,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 3.39000010490417,
#   'ModeratelyActiveDistance': 0.699999988079071,
#   'LightActiveDistance': 5.69000005722046,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 43,
#   'FairlyActiveMinutes': 18,
#   'LightlyActiveMinutes': 285,
#   'SedentaryMinutes': 757,
#   'Calories': 2030},
#  {'Id': 1503960366,
#   'ActivityDate': '4/5/2016',
#   'TotalSteps': 14844,
#   'TotalDistance': 9.72999954223633,
#   'TrackerDistance': 9.72999954223633,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 2.94000005722046,
#   'ModeratelyActiveDistance': 0.759999990463257,
#   'LightActiveDistance': 6.03999996185303,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 36,
#   'FairlyActiveMinutes': 18,
#   'LightlyActiveMinutes': 341,
#   'SedentaryMinutes': 736,
#   'Calories': 2083},
#  {'Id': 1503960366,
#   'ActivityDate': '4/6/2016',
#   'TotalSteps': 11974,
#   'TotalDistance': 7.67000007629395,
#   'TrackerDistance': 7.67000007629395,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 2.03999996185303,
#   'ModeratelyActiveDistance': 0.479999989271164,
#   'LightActiveDistance': 5.15000009536743,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 27,
#   'FairlyActiveMinutes': 12,
#   'LightlyActiveMinutes': 228,
#   'SedentaryMinutes': 1173,
#   'Calories': 1861},
#  {'Id': 1503960366,
#   'ActivityDate': '4/7/2016',
#   'TotalSteps': 10198,
#   'TotalDistance': 6.44000005722046,
#   'TrackerDistance': 6.44000005722046,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 1.20000004768372,
#   'ModeratelyActiveDistance': 0.790000021457672,
#   'LightActiveDistance': 4.44999980926514,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 17,
#   'FairlyActiveMinutes': 20,
#   'LightlyActiveMinutes': 195,
#   'SedentaryMinutes': 1208,
#   'Calories': 1755},
#  {'Id': 1503960366,
#   'ActivityDate': '4/8/2016',
#   'TotalSteps': 12521,
#   'TotalDistance': 7.94000005722046,
#   'TrackerDistance': 7.94000005722046,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 3.30999994277954,
#   'ModeratelyActiveDistance': 0.899999976158142,
#   'LightActiveDistance': 3.74000000953674,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 46,
#   'FairlyActiveMinutes': 22,
#   'LightlyActiveMinutes': 212,
#   'SedentaryMinutes': 1160,
#   'Calories': 1895},
#  {'Id': 1503960366,
#   'ActivityDate': '4/9/2016',
#   'TotalSteps': 12432,
#   'TotalDistance': 8.10000038146973,
#   'TrackerDistance': 8.10000038146973,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 2.58999991416931,
#   'ModeratelyActiveDistance': 0.589999973773956,
#   'LightActiveDistance': 4.92000007629395,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 32,
#   'FairlyActiveMinutes': 15,
#   'LightlyActiveMinutes': 248,
#   'SedentaryMinutes': 738,
#   'Calories': 1883},
#  {'Id': 1503960366,
#   'ActivityDate': '4/10/2016',
#   'TotalSteps': 10057,
#   'TotalDistance': 6.98000001907349,
#   'TrackerDistance': 6.98000001907349,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 4.0,
#   'ModeratelyActiveDistance': 0.490000009536743,
#   'LightActiveDistance': 2.48000001907349,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 44,
#   'FairlyActiveMinutes': 13,
#   'LightlyActiveMinutes': 168,
#   'SedentaryMinutes': 737,
#   'Calories': 1755},
#  {'Id': 1503960366,
#   'ActivityDate': '4/11/2016',
#   'TotalSteps': 10990,
#   'TotalDistance': 7.26000022888184,
#   'TrackerDistance': 7.26000022888184,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 2.03999996185303,
#   'ModeratelyActiveDistance': 0.569999992847443,
#   'LightActiveDistance': 4.65000009536743,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 26,
#   'FairlyActiveMinutes': 14,
#   'LightlyActiveMinutes': 216,
#   'SedentaryMinutes': 855,
#   'Calories': 1811},
#  {'Id': 1503960366,
#   'ActivityDate': '4/12/2016',
#   'TotalSteps': 224,
#   'TotalDistance': 0.140000000596046,
#   'TrackerDistance': 0.140000000596046,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 0.129999995231628,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 9,
#   'SedentaryMinutes': 32,
#   'Calories': 50},
#  {'Id': 1624580081,
#   'ActivityDate': '3/25/2016',
#   'TotalSteps': 1810,
#   'TotalDistance': 1.17999994754791,
#   'TrackerDistance': 1.17999994754791,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 1.12999999523163,
#   'SedentaryActiveDistance': 0.0099999997764825,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 121,
#   'SedentaryMinutes': 1319,
#   'Calories': 1373},
#  {'Id': 1624580081,
#   'ActivityDate': '3/26/2016',
#   'TotalSteps': 815,
#   'TotalDistance': 0.529999971389771,
#   'TrackerDistance': 0.529999971389771,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 0.529999971389771,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 47,
#   'SedentaryMinutes': 1393,
#   'Calories': 1264},
#  {'Id': 1624580081,
#   'ActivityDate': '3/27/2016',
#   'TotalSteps': 1985,
#   'TotalDistance': 1.28999996185303,
#   'TrackerDistance': 1.28999996185303,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 1.27999997138977,
#   'SedentaryActiveDistance': 0.0099999997764825,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 112,
#   'SedentaryMinutes': 1328,
#   'Calories': 1350},
#  {'Id': 1624580081,
#   'ActivityDate': '3/28/2016',
#   'TotalSteps': 1905,
#   'TotalDistance': 1.24000000953674,
#   'TrackerDistance': 1.24000000953674,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 1.24000000953674,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 95,
#   'SedentaryMinutes': 1345,
#   'Calories': 1342},
#  {'Id': 1624580081,
#   'ActivityDate': '3/29/2016',
#   'TotalSteps': 1552,
#   'TotalDistance': 1.00999999046326,
#   'TrackerDistance': 1.00999999046326,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 1.0,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 66,
#   'SedentaryMinutes': 1374,
#   'Calories': 1300},
#  {'Id': 1624580081,
#   'ActivityDate': '3/30/2016',
#   'TotalSteps': 1675,
#   'TotalDistance': 1.0900000333786,
#   'TrackerDistance': 1.0900000333786,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 1.0900000333786,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 84,
#   'SedentaryMinutes': 1356,
#   'Calories': 1313},
#  {'Id': 1624580081,
#   'ActivityDate': '3/31/2016',
#   'TotalSteps': 4506,
#   'TotalDistance': 2.9300000667572,
#   'TrackerDistance': 2.9300000667572,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.509999990463257,
#   'ModeratelyActiveDistance': 0.270000010728836,
#   'LightActiveDistance': 2.15000009536743,
#   'SedentaryActiveDistance': 0.0099999997764825,
#   'VeryActiveMinutes': 7,
#   'FairlyActiveMinutes': 4,
#   'LightlyActiveMinutes': 144,
#   'SedentaryMinutes': 1285,
#   'Calories': 1498},
#  {'Id': 1624580081,
#   'ActivityDate': '4/1/2016',
#   'TotalSteps': 9218,
#   'TotalDistance': 5.98999977111816,
#   'TrackerDistance': 5.98999977111816,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 5.96999979019165,
#   'SedentaryActiveDistance': 0.0099999997764825,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 221,
#   'SedentaryMinutes': 1219,
#   'Calories': 1541},
#  {'Id': 1624580081,
#   'ActivityDate': '4/2/2016',
#   'TotalSteps': 1556,
#   'TotalDistance': 1.00999999046326,
#   'TrackerDistance': 1.00999999046326,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 1.00999999046326,
#   'SedentaryActiveDistance': 0.0099999997764825,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 88,
#   'SedentaryMinutes': 1352,
#   'Calories': 1327},
#  {'Id': 1624580081,
#   'ActivityDate': '4/3/2016',
#   'TotalSteps': 2910,
#   'TotalDistance': 1.88999998569489,
#   'TrackerDistance': 1.88999998569489,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 1.87999999523163,
#   'SedentaryActiveDistance': 0.0099999997764825,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 157,
#   'SedentaryMinutes': 1283,
#   'Calories': 1452},
#  {'Id': 1624580081,
#   'ActivityDate': '4/4/2016',
#   'TotalSteps': 18464,
#   'TotalDistance': 12.0,
#   'TrackerDistance': 12.0,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 12.0,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 270,
#   'SedentaryMinutes': 1170,
#   'Calories': 1574},
#  {'Id': 1624580081,
#   'ActivityDate': '4/5/2016',
#   'TotalSteps': 1335,
#   'TotalDistance': 0.870000004768372,
#   'TrackerDistance': 0.870000004768372,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 0.870000004768372,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 74,
#   'SedentaryMinutes': 1366,
#   'Calories': 1308},
#  {'Id': 1624580081,
#   'ActivityDate': '4/6/2016',
#   'TotalSteps': 1004,
#   'TotalDistance': 0.649999976158142,
#   'TrackerDistance': 0.649999976158142,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 0.649999976158142,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 55,
#   'SedentaryMinutes': 1385,
#   'Calories': 1276},
#  {'Id': 1624580081,
#   'ActivityDate': '4/7/2016',
#   'TotalSteps': 1111,
#   'TotalDistance': 0.720000028610229,
#   'TrackerDistance': 0.720000028610229,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 0.720000028610229,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 54,
#   'SedentaryMinutes': 1386,
#   'Calories': 1278},
#  {'Id': 1624580081,
#   'ActivityDate': '4/8/2016',
#   'TotalSteps': 6344,
#   'TotalDistance': 4.11999988555908,
#   'TrackerDistance': 4.11999988555908,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 4.09999990463257,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 143,
#   'SedentaryMinutes': 1297,
#   'Calories': 1409},
#  {'Id': 1624580081,
#   'ActivityDate': '4/9/2016',
#   'TotalSteps': 3572,
#   'TotalDistance': 2.3199999332428,
#   'TrackerDistance': 2.3199999332428,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 2.28999996185303,
#   'SedentaryActiveDistance': 0.0299999993294477,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 122,
#   'SedentaryMinutes': 1318,
#   'Calories': 1370},
#  {'Id': 1624580081,
#   'ActivityDate': '4/10/2016',
#   'TotalSteps': 3910,
#   'TotalDistance': 2.53999996185303,
#   'TrackerDistance': 2.53999996185303,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.469999998807907,
#   'ModeratelyActiveDistance': 0.25,
#   'LightActiveDistance': 1.80999994277954,
#   'SedentaryActiveDistance': 0.0099999997764825,
#   'VeryActiveMinutes': 7,
#   'FairlyActiveMinutes': 7,
#   'LightlyActiveMinutes': 186,
#   'SedentaryMinutes': 1240,
#   'Calories': 1555},
#  {'Id': 1624580081,
#   'ActivityDate': '4/11/2016',
#   'TotalSteps': 10000,
#   'TotalDistance': 6.5,
#   'TrackerDistance': 6.5,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 6.5,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 172,
#   'SedentaryMinutes': 1268,
#   'Calories': 1469},
#  {'Id': 1624580081,
#   'ActivityDate': '4/12/2016',
#   'TotalSteps': 6627,
#   'TotalDistance': 4.30999994277954,
#   'TrackerDistance': 4.30999994277954,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 4.30999994277954,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 89,
#   'SedentaryMinutes': 604,
#   'Calories': 706},
#  {'Id': 1644430081,
#   'ActivityDate': '4/1/2016',
#   'TotalSteps': 4636,
#   'TotalDistance': 3.41000008583069,
#   'TrackerDistance': 3.41000008583069,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.779999971389771,
#   'LightActiveDistance': 2.59999990463257,
#   'SedentaryActiveDistance': 0.0299999993294477,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 16,
#   'LightlyActiveMinutes': 586,
#   'SedentaryMinutes': 838,
#   'Calories': 3323},
#  {'Id': 1644430081,
#   'ActivityDate': '4/2/2016',
#   'TotalSteps': 20237,
#   'TotalDistance': 14.710000038147,
#   'TrackerDistance': 14.710000038147,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 2.5699999332428,
#   'ModeratelyActiveDistance': 6.40000009536743,
#   'LightActiveDistance': 5.73000001907349,
#   'SedentaryActiveDistance': 0.0099999997764825,
#   'VeryActiveMinutes': 34,
#   'FairlyActiveMinutes': 141,
#   'LightlyActiveMinutes': 347,
#   'SedentaryMinutes': 918,
#   'Calories': 4029},
#  {'Id': 1644430081,
#   'ActivityDate': '4/3/2016',
#   'TotalSteps': 12912,
#   'TotalDistance': 9.40999984741211,
#   'TrackerDistance': 9.40999984741211,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 4.82999992370605,
#   'ModeratelyActiveDistance': 0.769999980926514,
#   'LightActiveDistance': 3.78999996185303,
#   'SedentaryActiveDistance': 0.0299999993294477,
#   'VeryActiveMinutes': 59,
#   'FairlyActiveMinutes': 16,
#   'LightlyActiveMinutes': 283,
#   'SedentaryMinutes': 1082,
#   'Calories': 3436},
#  {'Id': 1644430081,
#   'ActivityDate': '4/4/2016',
#   'TotalSteps': 2819,
#   'TotalDistance': 2.04999995231628,
#   'TrackerDistance': 2.04999995231628,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.310000002384186,
#   'ModeratelyActiveDistance': 0.170000001788139,
#   'LightActiveDistance': 1.55999994277954,
#   'SedentaryActiveDistance': 0.0099999997764825,
#   'VeryActiveMinutes': 4,
#   'FairlyActiveMinutes': 4,
#   'LightlyActiveMinutes': 87,
#   'SedentaryMinutes': 1345,
#   'Calories': 2444},
#  {'Id': 1644430081,
#   'ActivityDate': '4/5/2016',
#   'TotalSteps': 9921,
#   'TotalDistance': 7.21000003814697,
#   'TrackerDistance': 7.21000003814697,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.340000003576279,
#   'ModeratelyActiveDistance': 1.51999998092651,
#   'LightActiveDistance': 5.3600001335144,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 5,
#   'FairlyActiveMinutes': 35,
#   'LightlyActiveMinutes': 219,
#   'SedentaryMinutes': 1181,
#   'Calories': 3098},
#  {'Id': 1644430081,
#   'ActivityDate': '4/6/2016',
#   'TotalSteps': 8046,
#   'TotalDistance': 5.84999990463257,
#   'TrackerDistance': 5.84999990463257,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 1.28999996185303,
#   'ModeratelyActiveDistance': 2.11999988555908,
#   'LightActiveDistance': 2.45000004768372,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 18,
#   'FairlyActiveMinutes': 41,
#   'LightlyActiveMinutes': 137,
#   'SedentaryMinutes': 1244,
#   'Calories': 2925},
#  {'Id': 1644430081,
#   'ActivityDate': '4/7/2016',
#   'TotalSteps': 11166,
#   'TotalDistance': 8.11999988555908,
#   'TrackerDistance': 8.11999988555908,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.209999993443489,
#   'ModeratelyActiveDistance': 2.41000008583069,
#   'LightActiveDistance': 5.5,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 3,
#   'FairlyActiveMinutes': 58,
#   'LightlyActiveMinutes': 230,
#   'SedentaryMinutes': 1149,
#   'Calories': 3202},
#  {'Id': 1644430081,
#   'ActivityDate': '4/8/2016',
#   'TotalSteps': 7842,
#   'TotalDistance': 5.69999980926514,
#   'TrackerDistance': 5.69999980926514,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.479999989271164,
#   'ModeratelyActiveDistance': 2.41000008583069,
#   'LightActiveDistance': 2.80999994277954,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 7,
#   'FairlyActiveMinutes': 43,
#   'LightlyActiveMinutes': 161,
#   'SedentaryMinutes': 1229,
#   'Calories': 2928},
#  {'Id': 1644430081,
#   'ActivityDate': '4/9/2016',
#   'TotalSteps': 13840,
#   'TotalDistance': 10.0600004196167,
#   'TrackerDistance': 10.0600004196167,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 1.30999994277954,
#   'ModeratelyActiveDistance': 3.72000002861023,
#   'LightActiveDistance': 5.03000020980835,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 18,
#   'FairlyActiveMinutes': 81,
#   'LightlyActiveMinutes': 192,
#   'SedentaryMinutes': 1149,
#   'Calories': 3290},
#  {'Id': 1644430081,
#   'ActivityDate': '4/10/2016',
#   'TotalSteps': 1329,
#   'TotalDistance': 0.970000028610229,
#   'TrackerDistance': 0.970000028610229,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 0.970000028610229,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 35,
#   'SedentaryMinutes': 207,
#   'Calories': 489},
#  {'Id': 1844505072,
#   'ActivityDate': '4/1/2016',
#   'TotalSteps': 6847,
#   'TotalDistance': 4.53000020980835,
#   'TrackerDistance': 4.53000020980835,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.610000014305115,
#   'ModeratelyActiveDistance': 0.370000004768372,
#   'LightActiveDistance': 3.54999995231628,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 9,
#   'FairlyActiveMinutes': 9,
#   'LightlyActiveMinutes': 251,
#   'SedentaryMinutes': 1171,
#   'Calories': 1969},
#  {'Id': 1844505072,
#   'ActivityDate': '4/2/2016',
#   'TotalSteps': 5367,
#   'TotalDistance': 3.54999995231628,
#   'TrackerDistance': 3.54999995231628,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 3.54999995231628,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 263,
#   'SedentaryMinutes': 1177,
#   'Calories': 1889},
#  {'Id': 1844505072,
#   'ActivityDate': '4/3/2016',
#   'TotalSteps': 2841,
#   'TotalDistance': 1.87999999523163,
#   'TrackerDistance': 1.87999999523163,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 1.87999999523163,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 136,
#   'SedentaryMinutes': 1114,
#   'Calories': 1636},
#  {'Id': 1844505072,
#   'ActivityDate': '4/4/2016',
#   'TotalSteps': 0,
#   'TotalDistance': 0.0,
#   'TrackerDistance': 0.0,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 0.0,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 0,
#   'SedentaryMinutes': 669,
#   'Calories': 1347},
#  {'Id': 1844505072,
#   'ActivityDate': '4/5/2016',
#   'TotalSteps': 0,
#   'TotalDistance': 0.0,
#   'TrackerDistance': 0.0,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 0.0,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 0,
#   'SedentaryMinutes': 1440,
#   'Calories': 1347},
#  {'Id': 1844505072,
#   'ActivityDate': '4/6/2016',
#   'TotalSteps': 7,
#   'TotalDistance': 0.0,
#   'TrackerDistance': 0.0,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 0.0,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 1,
#   'SedentaryMinutes': 1439,
#   'Calories': 1349},
#  {'Id': 1844505072,
#   'ActivityDate': '4/7/2016',
#   'TotalSteps': 6344,
#   'TotalDistance': 4.19000005722046,
#   'TrackerDistance': 4.19000005722046,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 4.19000005722046,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 290,
#   'SedentaryMinutes': 1150,
#   'Calories': 1965},
#  {'Id': 1844505072,
#   'ActivityDate': '4/8/2016',
#   'TotalSteps': 5316,
#   'TotalDistance': 3.50999999046326,
#   'TrackerDistance': 3.50999999046326,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 3.50999999046326,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 221,
#   'SedentaryMinutes': 1219,
#   'Calories': 1824},
#  {'Id': 1844505072,
#   'ActivityDate': '4/9/2016',
#   'TotalSteps': 4979,
#   'TotalDistance': 3.28999996185303,
#   'TrackerDistance': 3.28999996185303,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 3.28999996185303,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 184,
#   'SedentaryMinutes': 620,
#   'Calories': 1807},
#  {'Id': 1844505072,
#   'ActivityDate': '4/10/2016',
#   'TotalSteps': 6556,
#   'TotalDistance': 4.34000015258789,
#   'TrackerDistance': 4.34000015258789,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 4.32999992370605,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 305,
#   'SedentaryMinutes': 810,
#   'Calories': 1971},
#  {'Id': 1844505072,
#   'ActivityDate': '4/11/2016',
#   'TotalSteps': 5430,
#   'TotalDistance': 3.58999991416931,
#   'TrackerDistance': 3.58999991416931,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 3.58999991416931,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 251,
#   'SedentaryMinutes': 1189,
#   'Calories': 1888},
#  {'Id': 1844505072,
#   'ActivityDate': '4/12/2016',
#   'TotalSteps': 0,
#   'TotalDistance': 0.0,
#   'TrackerDistance': 0.0,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 0.0,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 0,
#   'SedentaryMinutes': 426,
#   'Calories': 399},
#  {'Id': 1927972279,
#   'ActivityDate': '4/1/2016',
#   'TotalSteps': 4317,
#   'TotalDistance': 2.99000000953674,
#   'TrackerDistance': 2.99000000953674,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.370000004768372,
#   'LightActiveDistance': 2.61999988555908,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 11,
#   'LightlyActiveMinutes': 192,
#   'SedentaryMinutes': 854,
#   'Calories': 2590},
#  {'Id': 1927972279,
#   'ActivityDate': '4/2/2016',
#   'TotalSteps': 5662,
#   'TotalDistance': 3.92000007629395,
#   'TrackerDistance': 3.92000007629395,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 3.92000007629395,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 267,
#   'SedentaryMinutes': 858,
#   'Calories': 2783},
#  {'Id': 1927972279,
#   'ActivityDate': '4/3/2016',
#   'TotalSteps': 3198,
#   'TotalDistance': 2.21000003814697,
#   'TrackerDistance': 2.21000003814697,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 2.21000003814697,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 146,
#   'SedentaryMinutes': 1183,
#   'Calories': 2449},
#  {'Id': 1927972279,
#   'ActivityDate': '4/4/2016',
#   'TotalSteps': 2352,
#   'TotalDistance': 1.62999999523163,
#   'TrackerDistance': 1.62999999523163,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 1.62999999523163,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 128,
#   'SedentaryMinutes': 829,
#   'Calories': 2380},
#  {'Id': 1927972279,
#   'ActivityDate': '4/5/2016',
#   'TotalSteps': 2234,
#   'TotalDistance': 1.54999995231628,
#   'TrackerDistance': 1.54999995231628,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 1.54999995231628,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 108,
#   'SedentaryMinutes': 912,
#   'Calories': 2344},
#  {'Id': 1927972279,
#   'ActivityDate': '4/6/2016',
#   'TotalSteps': 1259,
#   'TotalDistance': 0.870000004768372,
#   'TrackerDistance': 0.870000004768372,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 0.870000004768372,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 73,
#   'SedentaryMinutes': 938,
#   'Calories': 2202},
#  {'Id': 1927972279,
#   'ActivityDate': '4/7/2016',
#   'TotalSteps': 768,
#   'TotalDistance': 0.529999971389771,
#   'TrackerDistance': 0.529999971389771,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 0.529999971389771,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 43,
#   'SedentaryMinutes': 1397,
#   'Calories': 2130},
#  {'Id': 1927972279,
#   'ActivityDate': '4/8/2016',
#   'TotalSteps': 519,
#   'TotalDistance': 0.360000014305115,
#   'TrackerDistance': 0.360000014305115,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 0.360000014305115,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 34,
#   'SedentaryMinutes': 1406,
#   'Calories': 2088},
#  {'Id': 1927972279,
#   'ActivityDate': '4/9/2016',
#   'TotalSteps': 2523,
#   'TotalDistance': 1.75,
#   'TrackerDistance': 1.75,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.370000004768372,
#   'LightActiveDistance': 1.37999999523163,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 9,
#   'LightlyActiveMinutes': 134,
#   'SedentaryMinutes': 1250,
#   'Calories': 2443},
#  {'Id': 1927972279,
#   'ActivityDate': '4/10/2016',
#   'TotalSteps': 2105,
#   'TotalDistance': 1.46000003814697,
#   'TrackerDistance': 1.46000003814697,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 1.46000003814697,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 139,
#   'SedentaryMinutes': 805,
#   'Calories': 2442},
#  {'Id': 1927972279,
#   'ActivityDate': '4/11/2016',
#   'TotalSteps': 1209,
#   'TotalDistance': 0.839999973773956,
#   'TrackerDistance': 0.839999973773956,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 0.839999973773956,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 73,
#   'SedentaryMinutes': 842,
#   'Calories': 2255},
#  {'Id': 1927972279,
#   'ActivityDate': '4/12/2016',
#   'TotalSteps': 24,
#   'TotalDistance': 0.0199999995529652,
#   'TrackerDistance': 0.0199999995529652,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 0.0199999995529652,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 3,
#   'SedentaryMinutes': 161,
#   'Calories': 942},
#  {'Id': 2022484408,
#   'ActivityDate': '4/1/2016',
#   'TotalSteps': 13603,
#   'TotalDistance': 9.60000038146973,
#   'TrackerDistance': 9.60000038146973,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 5.46000003814697,
#   'ModeratelyActiveDistance': 0.629999995231628,
#   'LightActiveDistance': 3.50999999046326,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 72,
#   'FairlyActiveMinutes': 16,
#   'LightlyActiveMinutes': 213,
#   'SedentaryMinutes': 1139,
#   'Calories': 2645},
#  {'Id': 2022484408,
#   'ActivityDate': '4/2/2016',
#   'TotalSteps': 5477,
#   'TotalDistance': 3.83999991416931,
#   'TrackerDistance': 3.83999991416931,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 3.83999991416931,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 237,
#   'SedentaryMinutes': 1203,
#   'Calories': 2040},
#  {'Id': 2022484408,
#   'ActivityDate': '4/3/2016',
#   'TotalSteps': 11144,
#   'TotalDistance': 7.82000017166138,
#   'TrackerDistance': 7.82000017166138,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 1.78999996185303,
#   'ModeratelyActiveDistance': 0.889999985694885,
#   'LightActiveDistance': 5.1399998664856,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 25,
#   'FairlyActiveMinutes': 22,
#   'LightlyActiveMinutes': 279,
#   'SedentaryMinutes': 1114,
#   'Calories': 2395},
#  {'Id': 2022484408,
#   'ActivityDate': '4/4/2016',
#   'TotalSteps': 15313,
#   'TotalDistance': 11.0,
#   'TrackerDistance': 11.0,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 5.01999998092651,
#   'ModeratelyActiveDistance': 1.28999996185303,
#   'LightActiveDistance': 4.69000005722046,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 62,
#   'FairlyActiveMinutes': 19,
#   'LightlyActiveMinutes': 233,
#   'SedentaryMinutes': 1126,
#   'Calories': 2581},
#  {'Id': 2022484408,
#   'ActivityDate': '4/5/2016',
#   'TotalSteps': 10805,
#   'TotalDistance': 7.59000015258789,
#   'TrackerDistance': 7.59000015258789,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.720000028610229,
#   'ModeratelyActiveDistance': 0.980000019073486,
#   'LightActiveDistance': 5.8899998664856,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 36,
#   'FairlyActiveMinutes': 37,
#   'LightlyActiveMinutes': 298,
#   'SedentaryMinutes': 1069,
#   'Calories': 2735},
#  {'Id': 2022484408,
#   'ActivityDate': '4/6/2016',
#   'TotalSteps': 15392,
#   'TotalDistance': 10.9300003051758,
#   'TrackerDistance': 10.9300003051758,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 3.4300000667572,
#   'ModeratelyActiveDistance': 1.75,
#   'LightActiveDistance': 5.75,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 47,
#   'FairlyActiveMinutes': 42,
#   'LightlyActiveMinutes': 258,
#   'SedentaryMinutes': 1093,
#   'Calories': 2733},
#  {'Id': 2022484408,
#   'ActivityDate': '4/7/2016',
#   'TotalSteps': 18247,
#   'TotalDistance': 13.8299999237061,
#   'TrackerDistance': 13.8299999237061,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 7.1100001335144,
#   'ModeratelyActiveDistance': 2.21000003814697,
#   'LightActiveDistance': 4.51000022888184,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 72,
#   'FairlyActiveMinutes': 62,
#   'LightlyActiveMinutes': 252,
#   'SedentaryMinutes': 1054,
#   'Calories': 3021},
#  {'Id': 2022484408,
#   'ActivityDate': '4/8/2016',
#   'TotalSteps': 13023,
#   'TotalDistance': 9.26000022888184,
#   'TrackerDistance': 9.26000022888184,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 3.23000001907349,
#   'ModeratelyActiveDistance': 0.560000002384186,
#   'LightActiveDistance': 5.46999979019165,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 40,
#   'FairlyActiveMinutes': 12,
#   'LightlyActiveMinutes': 296,
#   'SedentaryMinutes': 1092,
#   'Calories': 2577},
#  {'Id': 2022484408,
#   'ActivityDate': '4/9/2016',
#   'TotalSteps': 16267,
#   'TotalDistance': 12.5900001525879,
#   'TrackerDistance': 12.5900001525879,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 5.75,
#   'ModeratelyActiveDistance': 0.469999998807907,
#   'LightActiveDistance': 6.36999988555908,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 44,
#   'FairlyActiveMinutes': 16,
#   'LightlyActiveMinutes': 302,
#   'SedentaryMinutes': 1078,
#   'Calories': 2811},
#  {'Id': 2022484408,
#   'ActivityDate': '4/10/2016',
#   'TotalSteps': 10005,
#   'TotalDistance': 7.01999998092651,
#   'TrackerDistance': 7.01999998092651,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0799999982118607,
#   'ModeratelyActiveDistance': 1.04999995231628,
#   'LightActiveDistance': 5.90000009536743,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 1,
#   'FairlyActiveMinutes': 23,
#   'LightlyActiveMinutes': 339,
#   'SedentaryMinutes': 1077,
#   'Calories': 2458},
#  {'Id': 2022484408,
#   'ActivityDate': '4/11/2016',
#   'TotalSteps': 10106,
#   'TotalDistance': 7.09000015258789,
#   'TrackerDistance': 7.09000015258789,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 1.21000003814697,
#   'ModeratelyActiveDistance': 0.560000002384186,
#   'LightActiveDistance': 5.32999992370605,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 41,
#   'FairlyActiveMinutes': 16,
#   'LightlyActiveMinutes': 272,
#   'SedentaryMinutes': 1111,
#   'Calories': 2568},
#  {'Id': 2022484408,
#   'ActivityDate': '4/12/2016',
#   'TotalSteps': 6717,
#   'TotalDistance': 4.71999979019165,
#   'TrackerDistance': 4.71999979019165,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 3.23000001907349,
#   'ModeratelyActiveDistance': 0.219999998807907,
#   'LightActiveDistance': 1.26999998092651,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 41,
#   'FairlyActiveMinutes': 5,
#   'LightlyActiveMinutes': 67,
#   'SedentaryMinutes': 551,
#   'Calories': 1140},
#  {'Id': 2026352035,
#   'ActivityDate': '4/1/2016',
#   'TotalSteps': 2605,
#   'TotalDistance': 1.62000000476837,
#   'TrackerDistance': 1.62000000476837,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 1.62000000476837,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 166,
#   'SedentaryMinutes': 729,
#   'Calories': 1407},
#  {'Id': 2026352035,
#   'ActivityDate': '4/2/2016',
#   'TotalSteps': 1229,
#   'TotalDistance': 0.759999990463257,
#   'TrackerDistance': 0.759999990463257,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 0.759999990463257,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 69,
#   'SedentaryMinutes': 795,
#   'Calories': 1237},
#  {'Id': 2026352035,
#   'ActivityDate': '4/3/2016',
#   'TotalSteps': 2308,
#   'TotalDistance': 1.42999994754791,
#   'TrackerDistance': 1.42999994754791,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 1.42999994754791,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 115,
#   'SedentaryMinutes': 720,
#   'Calories': 1330},
#  {'Id': 2026352035,
#   'ActivityDate': '4/4/2016',
#   'TotalSteps': 6679,
#   'TotalDistance': 4.1399998664856,
#   'TrackerDistance': 4.1399998664856,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 4.1399998664856,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 263,
#   'SedentaryMinutes': 644,
#   'Calories': 1583},
#  {'Id': 2026352035,
#   'ActivityDate': '4/5/2016',
#   'TotalSteps': 5645,
#   'TotalDistance': 3.5,
#   'TrackerDistance': 3.5,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 3.5,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 248,
#   'SedentaryMinutes': 621,
#   'Calories': 1538},
#  {'Id': 2026352035,
#   'ActivityDate': '4/6/2016',
#   'TotalSteps': 3180,
#   'TotalDistance': 1.97000002861023,
#   'TrackerDistance': 1.97000002861023,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 1.97000002861023,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 185,
#   'SedentaryMinutes': 738,
#   'Calories': 1421},
#  {'Id': 2026352035,
#   'ActivityDate': '4/7/2016',
#   'TotalSteps': 2767,
#   'TotalDistance': 1.72000002861023,
#   'TrackerDistance': 1.72000002861023,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 1.72000002861023,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 170,
#   'SedentaryMinutes': 673,
#   'Calories': 1392},
#  {'Id': 2026352035,
#   'ActivityDate': '4/8/2016',
#   'TotalSteps': 3762,
#   'TotalDistance': 2.32999992370605,
#   'TrackerDistance': 2.32999992370605,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 2.32999992370605,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 173,
#   'SedentaryMinutes': 719,
#   'Calories': 1425},
#  {'Id': 2026352035,
#   'ActivityDate': '4/9/2016',
#   'TotalSteps': 3098,
#   'TotalDistance': 1.91999995708466,
#   'TrackerDistance': 1.91999995708466,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 1.91999995708466,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 185,
#   'SedentaryMinutes': 700,
#   'Calories': 1413},
#  {'Id': 2026352035,
#   'ActivityDate': '4/10/2016',
#   'TotalSteps': 5142,
#   'TotalDistance': 3.19000005722046,
#   'TrackerDistance': 3.19000005722046,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 3.19000005722046,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 230,
#   'SedentaryMinutes': 654,
#   'Calories': 1515},
#  {'Id': 2026352035,
#   'ActivityDate': '4/11/2016',
#   'TotalSteps': 3279,
#   'TotalDistance': 2.02999997138977,
#   'TrackerDistance': 2.02999997138977,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 2.02999997138977,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 164,
#   'SedentaryMinutes': 694,
#   'Calories': 1405},
#  {'Id': 2026352035,
#   'ActivityDate': '4/12/2016',
#   'TotalSteps': 1019,
#   'TotalDistance': 0.629999995231628,
#   'TrackerDistance': 0.629999995231628,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 0.629999995231628,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 64,
#   'SedentaryMinutes': 223,
#   'Calories': 600},
#  {'Id': 2320127002,
#   'ActivityDate': '4/1/2016',
#   'TotalSteps': 0,
#   'TotalDistance': 0.0,
#   'TrackerDistance': 0.0,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 0.0,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 0,
#   'SedentaryMinutes': 1440,
#   'Calories': 1324},
#  {'Id': 2320127002,
#   'ActivityDate': '4/2/2016',
#   'TotalSteps': 0,
#   'TotalDistance': 0.0,
#   'TrackerDistance': 0.0,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 0.0,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 0,
#   'SedentaryMinutes': 1440,
#   'Calories': 1324},
#  {'Id': 2320127002,
#   'ActivityDate': '4/3/2016',
#   'TotalSteps': 0,
#   'TotalDistance': 0.0,
#   'TrackerDistance': 0.0,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 0.0,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 0,
#   'SedentaryMinutes': 1440,
#   'Calories': 1324},
#  {'Id': 2320127002,
#   'ActivityDate': '4/4/2016',
#   'TotalSteps': 0,
#   'TotalDistance': 0.0,
#   'TrackerDistance': 0.0,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 0.0,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 0,
#   'SedentaryMinutes': 1440,
#   'Calories': 1324},
#  {'Id': 2320127002,
#   'ActivityDate': '4/5/2016',
#   'TotalSteps': 4931,
#   'TotalDistance': 3.3199999332428,
#   'TrackerDistance': 3.3199999332428,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 3.3199999332428,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 175,
#   'SedentaryMinutes': 1265,
#   'Calories': 1708},
#  {'Id': 2320127002,
#   'ActivityDate': '4/6/2016',
#   'TotalSteps': 6999,
#   'TotalDistance': 4.71999979019165,
#   'TrackerDistance': 4.71999979019165,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 4.71999979019165,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 320,
#   'SedentaryMinutes': 1120,
#   'Calories': 1950},
#  {'Id': 2320127002,
#   'ActivityDate': '4/7/2016',
#   'TotalSteps': 1846,
#   'TotalDistance': 1.24000000953674,
#   'TrackerDistance': 1.24000000953674,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 1.24000000953674,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 93,
#   'SedentaryMinutes': 1347,
#   'Calories': 1508},
#  {'Id': 2320127002,
#   'ActivityDate': '4/8/2016',
#   'TotalSteps': 3417,
# ...
#   'VeryActiveDistance': 1.53999996185303,
#   'ModeratelyActiveDistance': 0.879999995231628,
#   'LightActiveDistance': 4.59000015258789,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 74,
#   'FairlyActiveMinutes': 17,
#   'LightlyActiveMinutes': 182,
#   'SedentaryMinutes': 811,
#   'Calories': 3775},
#  {'Id': 8378563200,
#   'ActivityDate': '4/12/2016',
#   'TotalSteps': 3246,
#   'TotalDistance': 2.5699999332428,
#   'TrackerDistance': 2.5699999332428,
#   'LoggedActivitiesDistance': 2.25308108329773,
#   'VeryActiveDistance': 0.829999983310699,
#   'ModeratelyActiveDistance': 0.709999978542328,
#   'LightActiveDistance': 1.02999997138977,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 65,
#   'FairlyActiveMinutes': 15,
#   'LightlyActiveMinutes': 49,
#   'SedentaryMinutes': 243,
#   'Calories': 1882},
#  {'Id': 8583815059,
#   'ActivityDate': '4/1/2016',
#   'TotalSteps': 2174,
#   'TotalDistance': 1.70000004768372,
#   'TrackerDistance': 1.70000004768372,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 1.70000004768372,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 112,
#   'SedentaryMinutes': 1328,
#   'Calories': 2360},
#  {'Id': 8583815059,
#   'ActivityDate': '4/2/2016',
#   'TotalSteps': 3494,
#   'TotalDistance': 2.73000001907349,
#   'TrackerDistance': 2.73000001907349,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 2.69000005722046,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 166,
#   'SedentaryMinutes': 1274,
#   'Calories': 2517},
#  {'Id': 8583815059,
#   'ActivityDate': '4/3/2016',
#   'TotalSteps': 2380,
#   'TotalDistance': 1.86000001430511,
#   'TrackerDistance': 1.86000001430511,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 1.86000001430511,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 131,
#   'SedentaryMinutes': 1309,
#   'Calories': 2400},
#  {'Id': 8583815059,
#   'ActivityDate': '4/4/2016',
#   'TotalSteps': 3159,
#   'TotalDistance': 2.46000003814697,
#   'TrackerDistance': 2.46000003814697,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 2.46000003814697,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 147,
#   'SedentaryMinutes': 1293,
#   'Calories': 2462},
#  {'Id': 8583815059,
#   'ActivityDate': '4/5/2016',
#   'TotalSteps': 6835,
#   'TotalDistance': 5.32999992370605,
#   'TrackerDistance': 5.32999992370605,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.370000004768372,
#   'ModeratelyActiveDistance': 0.730000019073486,
#   'LightActiveDistance': 4.23999977111816,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 5,
#   'FairlyActiveMinutes': 15,
#   'LightlyActiveMinutes': 212,
#   'SedentaryMinutes': 1208,
#   'Calories': 2786},
#  {'Id': 8583815059,
#   'ActivityDate': '4/6/2016',
#   'TotalSteps': 2098,
#   'TotalDistance': 1.63999998569489,
#   'TrackerDistance': 1.63999998569489,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 1.62999999523163,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 112,
#   'SedentaryMinutes': 1328,
#   'Calories': 2354},
#  {'Id': 8583815059,
#   'ActivityDate': '4/7/2016',
#   'TotalSteps': 2816,
#   'TotalDistance': 2.20000004768372,
#   'TrackerDistance': 2.20000004768372,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 2.20000004768372,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 138,
#   'SedentaryMinutes': 1302,
#   'Calories': 2437},
#  {'Id': 8583815059,
#   'ActivityDate': '4/8/2016',
#   'TotalSteps': 1408,
#   'TotalDistance': 1.10000002384186,
#   'TrackerDistance': 1.10000002384186,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 1.10000002384186,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 79,
#   'SedentaryMinutes': 1052,
#   'Calories': 1814},
#  {'Id': 8792009665,
#   'ActivityDate': '4/1/2016',
#   'TotalSteps': 4592,
#   'TotalDistance': 2.94000005722046,
#   'TrackerDistance': 2.94000005722046,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.100000001490116,
#   'ModeratelyActiveDistance': 0.140000000596046,
#   'LightActiveDistance': 2.70000004768372,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 4,
#   'FairlyActiveMinutes': 8,
#   'LightlyActiveMinutes': 176,
#   'SedentaryMinutes': 748,
#   'Calories': 2260},
#  {'Id': 8792009665,
#   'ActivityDate': '4/2/2016',
#   'TotalSteps': 8452,
#   'TotalDistance': 5.40999984741211,
#   'TrackerDistance': 5.40999984741211,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.259999990463257,
#   'ModeratelyActiveDistance': 0.389999985694885,
#   'LightActiveDistance': 4.76000022888184,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 9,
#   'FairlyActiveMinutes': 24,
#   'LightlyActiveMinutes': 328,
#   'SedentaryMinutes': 1079,
#   'Calories': 3004},
#  {'Id': 8792009665,
#   'ActivityDate': '4/3/2016',
#   'TotalSteps': 7238,
#   'TotalDistance': 4.63000011444092,
#   'TrackerDistance': 4.63000011444092,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.109999999403954,
#   'ModeratelyActiveDistance': 0.230000004172325,
#   'LightActiveDistance': 4.28999996185303,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 2,
#   'FairlyActiveMinutes': 6,
#   'LightlyActiveMinutes': 279,
#   'SedentaryMinutes': 636,
#   'Calories': 2667},
#  {'Id': 8792009665,
#   'ActivityDate': '4/4/2016',
#   'TotalSteps': 3821,
#   'TotalDistance': 2.45000004768372,
#   'TrackerDistance': 2.45000004768372,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.219999998807907,
#   'LightActiveDistance': 2.23000001907349,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 9,
#   'LightlyActiveMinutes': 161,
#   'SedentaryMinutes': 675,
#   'Calories': 2229},
#  {'Id': 8792009665,
#   'ActivityDate': '4/5/2016',
#   'TotalSteps': 2332,
#   'TotalDistance': 1.49000000953674,
#   'TrackerDistance': 1.49000000953674,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0099999997764825,
#   'ModeratelyActiveDistance': 0.180000007152557,
#   'LightActiveDistance': 1.29999995231628,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 1,
#   'FairlyActiveMinutes': 10,
#   'LightlyActiveMinutes': 111,
#   'SedentaryMinutes': 904,
#   'Calories': 2100},
#  {'Id': 8792009665,
#   'ActivityDate': '4/6/2016',
#   'TotalSteps': 2121,
#   'TotalDistance': 1.36000001430511,
#   'TrackerDistance': 1.36000001430511,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 1.36000001430511,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 122,
#   'SedentaryMinutes': 855,
#   'Calories': 2114},
#  {'Id': 8792009665,
#   'ActivityDate': '4/7/2016',
#   'TotalSteps': 1291,
#   'TotalDistance': 0.829999983310699,
#   'TrackerDistance': 0.829999983310699,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 0.829999983310699,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 77,
#   'SedentaryMinutes': 888,
#   'Calories': 1961},
#  {'Id': 8792009665,
#   'ActivityDate': '4/8/2016',
#   'TotalSteps': 1467,
#   'TotalDistance': 0.939999997615814,
#   'TrackerDistance': 0.939999997615814,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.100000001490116,
#   'ModeratelyActiveDistance': 0.209999993443489,
#   'LightActiveDistance': 0.629999995231628,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 2,
#   'FairlyActiveMinutes': 8,
#   'LightlyActiveMinutes': 71,
#   'SedentaryMinutes': 912,
#   'Calories': 1953},
#  {'Id': 8792009665,
#   'ActivityDate': '4/9/2016',
#   'TotalSteps': 1022,
#   'TotalDistance': 0.649999976158142,
#   'TrackerDistance': 0.649999976158142,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 0.649999976158142,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 63,
#   'SedentaryMinutes': 739,
#   'Calories': 1890},
#  {'Id': 8792009665,
#   'ActivityDate': '4/10/2016',
#   'TotalSteps': 4605,
#   'TotalDistance': 2.95000004768372,
#   'TrackerDistance': 2.95000004768372,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 2.95000004768372,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 179,
#   'SedentaryMinutes': 1261,
#   'Calories': 2253},
#  {'Id': 8792009665,
#   'ActivityDate': '4/11/2016',
#   'TotalSteps': 178,
#   'TotalDistance': 0.109999999403954,
#   'TrackerDistance': 0.109999999403954,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 0.109999999403954,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 12,
#   'SedentaryMinutes': 1428,
#   'Calories': 1725},
#  {'Id': 8792009665,
#   'ActivityDate': '4/12/2016',
#   'TotalSteps': 20,
#   'TotalDistance': 0.0099999997764825,
#   'TrackerDistance': 0.0099999997764825,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 0.0099999997764825,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 6,
#   'SedentaryMinutes': 598,
#   'Calories': 728},
#  {'Id': 8877689391,
#   'ActivityDate': '4/1/2016',
#   'TotalSteps': 18700,
#   'TotalDistance': 15.8199996948242,
#   'TrackerDistance': 15.8199996948242,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 8.69999980926514,
#   'ModeratelyActiveDistance': 0.159999996423721,
#   'LightActiveDistance': 6.90999984741211,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 67,
#   'FairlyActiveMinutes': 3,
#   'LightlyActiveMinutes': 247,
#   'SedentaryMinutes': 1123,
#   'Calories': 3527},
#  {'Id': 8877689391,
#   'ActivityDate': '4/2/2016',
#   'TotalSteps': 27572,
#   'TotalDistance': 23.3899993896484,
#   'TrackerDistance': 23.3899993896484,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 14.7200002670288,
#   'ModeratelyActiveDistance': 1.21000003814697,
#   'LightActiveDistance': 7.34000015258789,
#   'SedentaryActiveDistance': 0.0099999997764825,
#   'VeryActiveMinutes': 116,
#   'FairlyActiveMinutes': 24,
#   'LightlyActiveMinutes': 260,
#   'SedentaryMinutes': 1040,
#   'Calories': 4220},
#  {'Id': 8877689391,
#   'ActivityDate': '4/3/2016',
#   'TotalSteps': 15260,
#   'TotalDistance': 8.1899995803833,
#   'TrackerDistance': 8.1899995803833,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 1.79999995231628,
#   'ModeratelyActiveDistance': 0.75,
#   'LightActiveDistance': 5.57000017166138,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 106,
#   'FairlyActiveMinutes': 17,
#   'LightlyActiveMinutes': 259,
#   'SedentaryMinutes': 1058,
#   'Calories': 3864},
#  {'Id': 8877689391,
#   'ActivityDate': '4/4/2016',
#   'TotalSteps': 20779,
#   'TotalDistance': 18.4099998474121,
#   'TrackerDistance': 18.4099998474121,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 11.7299995422363,
#   'ModeratelyActiveDistance': 0.649999976158142,
#   'LightActiveDistance': 6.0,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 78,
#   'FairlyActiveMinutes': 16,
#   'LightlyActiveMinutes': 208,
#   'SedentaryMinutes': 1138,
#   'Calories': 3662},
#  {'Id': 8877689391,
#   'ActivityDate': '4/5/2016',
#   'TotalSteps': 10695,
#   'TotalDistance': 8.11999988555908,
#   'TrackerDistance': 8.11999988555908,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.769999980926514,
#   'ModeratelyActiveDistance': 0.180000007152557,
#   'LightActiveDistance': 7.09000015258789,
#   'SedentaryActiveDistance': 0.0099999997764825,
#   'VeryActiveMinutes': 10,
#   'FairlyActiveMinutes': 3,
#   'LightlyActiveMinutes': 246,
#   'SedentaryMinutes': 1181,
#   'Calories': 2834},
#  {'Id': 8877689391,
#   'ActivityDate': '4/6/2016',
#   'TotalSteps': 24136,
#   'TotalDistance': 20.9099998474121,
#   'TrackerDistance': 20.9099998474121,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 12.2200002670288,
#   'ModeratelyActiveDistance': 0.540000021457672,
#   'LightActiveDistance': 8.07999992370605,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 87,
#   'FairlyActiveMinutes': 16,
#   'LightlyActiveMinutes': 318,
#   'SedentaryMinutes': 1019,
#   'Calories': 4039},
#  {'Id': 8877689391,
#   'ActivityDate': '4/7/2016',
#   'TotalSteps': 10910,
#   'TotalDistance': 8.42000007629395,
#   'TrackerDistance': 8.42000007629395,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 2.96000003814697,
#   'ModeratelyActiveDistance': 0.389999985694885,
#   'LightActiveDistance': 5.03000020980835,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 32,
#   'FairlyActiveMinutes': 11,
#   'LightlyActiveMinutes': 212,
#   'SedentaryMinutes': 1185,
#   'Calories': 2947},
#  {'Id': 8877689391,
#   'ActivityDate': '4/8/2016',
#   'TotalSteps': 23014,
#   'TotalDistance': 20.3899993896484,
#   'TrackerDistance': 20.3899993896484,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 11.1000003814697,
#   'ModeratelyActiveDistance': 0.629999995231628,
#   'LightActiveDistance': 8.61999988555908,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 70,
#   'FairlyActiveMinutes': 29,
#   'LightlyActiveMinutes': 359,
#   'SedentaryMinutes': 982,
#   'Calories': 4196},
#  {'Id': 8877689391,
#   'ActivityDate': '4/9/2016',
#   'TotalSteps': 16470,
#   'TotalDistance': 8.06999969482422,
#   'TrackerDistance': 8.06999969482422,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0199999995529652,
#   'LightActiveDistance': 8.02000045776367,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 90,
#   'FairlyActiveMinutes': 9,
#   'LightlyActiveMinutes': 289,
#   'SedentaryMinutes': 1052,
#   'Calories': 3841},
#  {'Id': 8877689391,
#   'ActivityDate': '4/10/2016',
#   'TotalSteps': 28497,
#   'TotalDistance': 27.5300006866455,
#   'TrackerDistance': 27.5300006866455,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 21.9200000762939,
#   'ModeratelyActiveDistance': 1.12000000476837,
#   'LightActiveDistance': 4.46000003814697,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 128,
#   'FairlyActiveMinutes': 46,
#   'LightlyActiveMinutes': 211,
#   'SedentaryMinutes': 1055,
#   'Calories': 4526},
#  {'Id': 8877689391,
#   'ActivityDate': '4/11/2016',
#   'TotalSteps': 10622,
#   'TotalDistance': 8.0600004196167,
#   'TrackerDistance': 8.0600004196167,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 1.47000002861023,
#   'ModeratelyActiveDistance': 0.150000005960464,
#   'LightActiveDistance': 6.36999988555908,
#   'SedentaryActiveDistance': 0.0099999997764825,
#   'VeryActiveMinutes': 18,
#   'FairlyActiveMinutes': 7,
#   'LightlyActiveMinutes': 225,
#   'SedentaryMinutes': 1190,
#   'Calories': 2820},
#  {'Id': 8877689391,
#   'ActivityDate': '4/12/2016',
#   'TotalSteps': 2350,
#   'TotalDistance': 1.77999997138977,
#   'TrackerDistance': 1.77999997138977,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 0.0,
#   'ModeratelyActiveDistance': 0.0,
#   'LightActiveDistance': 1.77999997138977,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 0,
#   'FairlyActiveMinutes': 0,
#   'LightlyActiveMinutes': 58,
#   'SedentaryMinutes': 531,
#   'Calories': 938}]

# %%
coll.insert_many(data)

# %% [markdown]
# # 3. convert all the dates avaible in dataset to timestamp format in pandas and in sql you to convert it in date format

# %% [markdown]
# ## in pandas

# %%
df.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    3/25/2016       11004           7.11             7.11
# 1  1503960366    3/26/2016       17609          11.55            11.55
# 2  1503960366    3/27/2016       12736           8.53             8.53
# 3  1503960366    3/28/2016       13231           8.93             8.93
# 4  1503960366    3/29/2016       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                 4.07                      0.0                 33
# 1                 3.91                      0.0                 89
# 2                 3.71                      0.0                 56
# 3                 4.95                      0.0                 39
# 4                 4.61                      0.0                 28
#
#    FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 0                   12                   205               804      1819
# 1                   17                   274               588      2154
# 2                    5                   268               605      1944
# 3                   20                   224              1080      1932
# 4                   28                   243               763      1886

# %%
df.dtypes
# Out:
# Id                            int64
# ActivityDate                 object
# TotalSteps                    int64
# TotalDistance               float64
# TrackerDistance             float64
# LoggedActivitiesDistance    float64
# VeryActiveDistance          float64
# ModeratelyActiveDistance    float64
# LightActiveDistance         float64
# SedentaryActiveDistance     float64
# VeryActiveMinutes             int64
# FairlyActiveMinutes           int64
# LightlyActiveMinutes          int64
# SedentaryMinutes              int64
# Calories                      int64
# dtype: object

# %%
df["ActivityDate"]=pd.to_datetime(df["ActivityDate"])

# %%
df
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366   2016-03-25       11004       7.110000         7.110000
# 1    1503960366   2016-03-26       17609      11.550000        11.550000
# 2    1503960366   2016-03-27       12736       8.530000         8.530000
# 3    1503960366   2016-03-28       13231       8.930000         8.930000
# 4    1503960366   2016-03-29       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391   2016-04-08       23014      20.389999        20.389999
# 453  8877689391   2016-04-09       16470       8.070000         8.070000
# 454  8877689391   2016-04-10       28497      27.530001        27.530001
# 455  8877689391   2016-04-11       10622       8.060000         8.060000
# 456  8877689391   2016-04-12        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                         0.0                2.57                      0.46
# 1                         0.0                6.92                      0.73
# 2                         0.0                4.66                      0.16
# 3                         0.0                3.19                      0.79
# 4                         0.0                2.16                      1.09
# ..                        ...                 ...                       ...
# 452                       0.0               11.10                      0.63
# 453                       0.0                0.00                      0.02
# 454                       0.0               21.92                      1.12
# 455                       0.0                1.47                      0.15
# 456                       0.0                0.00                      0.00
#
#      LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                   4.07                     0.00                 33
# 1                   3.91                     0.00                 89
# 2                   3.71                     0.00                 56
# 3                   4.95                     0.00                 39
# 4                   4.61                     0.00                 28
# ..                   ...                      ...                ...
# 452                 8.62                     0.00                 70
# 453                 8.02                     0.00                 90
# 454                 4.46                     0.00                128
# 455                 6.37                     0.01                 18
# 456                 1.78                     0.00                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 0                     12                   205               804      1819
# 1                     17                   274               588      2154
# 2                      5                   268               605      1944
# 3                     20                   224              1080      1932
# 4                     28                   243               763      1886
# ..                   ...                   ...               ...       ...
# 452                   29                   359               982      4196
# 453                    9                   289              1052      3841
# 454                   46                   211              1055      4526
# 455                    7                   225              1190      2820
# 456                    0                    58               531       938
#
# [457 rows x 15 columns]

# %% [markdown]
# ## querys in sql

# %% [raw]
# select * , cast(ActivityDate as datetime) as 'Date'
# from pandastask3.fitbit_data

# %% [markdown]
# # 4 . Find out in this data that how many unique id's we have

# %% [markdown]
# ## in sql

# %% [raw]
# use pandastask3;
# select DISTINCT Id as uniqueId
# from fitbit_data

# %% [markdown]
# ## in pandas

# %%
df.Id.unique()
# Out:
# array([1503960366, 1624580081, 1644430081, 1844505072, 1927972279,
#        2022484408, 2026352035, 2320127002, 2347167796, 2873212765,
#        2891001357, 3372868164, 3977333714, 4020332650, 4057192912,
#        4319703577, 4388161847, 4445114986, 4558609924, 4702921684,
#        5553957443, 5577150313, 6117666160, 6290855005, 6391747486,
#        6775888955, 6962181067, 7007744171, 7086361926, 8053475328,
#        8253242879, 8378563200, 8583815059, 8792009665, 8877689391],
#       dtype=int64)

# %% [markdown]
# # 5 . which id is one of the active id that you have in whole dataset

# %% [markdown]
# ## In sql

# %% [raw]
# use pandastask3;
# select Id, sum(Calories)
# from fitbit_data
# group by Id
# order by Calories DESC
# limit 1

# %% [markdown]
# ## In pandas

# %%
df.groupby(df["Id"])[["Calories"]].sum().sort_values('Calories' , ascending = False).head(1)
# Out:
#             Calories
# Id
# 4020332650     98412

# %% [markdown]
# # 6 . how many of them have not logged there activity find out in terms of number of ids

# %% [markdown]
# ## In sql

# %% [raw]
# use pandastask3;
# select count(Id) , LoggedActivitiesDistance
# from fitbit_data
# where LoggedActivitiesDistance = "0"

# %% [markdown]
# ## In pandas

# %%
df[df["LoggedActivitiesDistance"] == 0][["Id", "LoggedActivitiesDistance"]]
# Out:
#              Id  LoggedActivitiesDistance
# 0    1503960366                       0.0
# 1    1503960366                       0.0
# 2    1503960366                       0.0
# 3    1503960366                       0.0
# 4    1503960366                       0.0
# ..          ...                       ...
# 452  8877689391                       0.0
# 453  8877689391                       0.0
# 454  8877689391                       0.0
# 455  8877689391                       0.0
# 456  8877689391                       0.0
#
# [433 rows x 2 columns]

# %% [markdown]
# # 7 . Find out who is the laziest person id that we have in dataset

# %% [markdown]
# ## In sql

# %% [raw]
# use pandastask3;
# select Id, sum(Calories)
# from fitbit_data
# group by Id
# order by Calories
# limit 1

# %% [markdown]
# ## In pandas

# %%
df.groupby(df["Id"])[["Calories"]].sum().sort_values('Calories' , ascending = True).head(1)
# Out:
#             Calories
# Id
# 4388161847     14442

# %% [markdown]
# # 8 . Explore over an internet that how much calories burn is required for a healthy person and find out how many healthy person we have in our dataset

# %% [markdown]
# ## In sql

# %% [raw]
# use pandastask3;
# select Id, avg(Calories) as avgcal
# from fitbit_data
# group by Id
# having avgcal > 1600
# order by Calories

# %% [markdown]
# ## In pandas

# %%
df2 = df.groupby(df["Id"])[["Calories"]].mean().sort_values('Calories' , ascending = False)

# %%
df2[df2["Calories"] > 1600]
# Out:
#                Calories
# Id
# 8877689391  3451.166667
# 8378563200  3356.166667
# 5577150313  3300.272727
# 4020332650  3075.375000
# 1644430081  2916.400000
# 8053475328  2893.181818
# 4702921684  2821.466667
# 6775888955  2724.777778
# 7007744171  2627.083333
# 2022484408  2475.333333
# 8583815059  2391.250000
# 2891001357  2273.375000
# 1927972279  2254.000000
# 7086361926  2177.000000
# 6290855005  2165.600000
# 4445114986  2107.800000
# 6117666160  2099.300000
# 6962181067  2089.214286
# 8792009665  2073.666667
# 2347167796  2021.333333
# 4319703577  1994.250000
# 4057192912  1903.531250
# 3372868164  1860.300000
# 4558609924  1830.166667
# 4388161847  1805.250000
# 5553957443  1802.500000
# 1503960366  1796.210526
# 6391747486  1763.111111
# 2873212765  1695.750000
# 1844505072  1615.916667

# %% [markdown]
# # 9. how many person are not a regular person with respect to activity try to find out those

# %% [markdown]
# ## In sql

# %% [raw]
# use pandastask3;
# select *
# from fitbit_data
# where TotalSteps=0 and TotalDistance=0 and TrackerDistance=0

# %% [markdown]
# ## In pandas

# %%
df[(df["TotalSteps"] == 0) & (df["TotalDistance"] == 0) & (df["TrackerDistance"] == 0)]
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 51   1844505072     4/4/2016           0            0.0              0.0
# 52   1844505072     4/5/2016           0            0.0              0.0
# 59   1844505072    4/12/2016           0            0.0              0.0
# 96   2320127002     4/1/2016           0            0.0              0.0
# 97   2320127002     4/2/2016           0            0.0              0.0
# ..          ...          ...         ...            ...              ...
# 402  8253242879     4/2/2016           0            0.0              0.0
# 403  8253242879     4/3/2016           0            0.0              0.0
# 404  8253242879     4/4/2016           0            0.0              0.0
# 405  8253242879     4/5/2016           0            0.0              0.0
# 412  8253242879    4/12/2016           0            0.0              0.0
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 51                        0.0                 0.0                       0.0
# 52                        0.0                 0.0                       0.0
# 59                        0.0                 0.0                       0.0
# 96                        0.0                 0.0                       0.0
# 97                        0.0                 0.0                       0.0
# ..                        ...                 ...                       ...
# 402                       0.0                 0.0                       0.0
# 403                       0.0                 0.0                       0.0
# 404                       0.0                 0.0                       0.0
# 405                       0.0                 0.0                       0.0
# 412                       0.0                 0.0                       0.0
#
#      LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 51                   0.0                      0.0                  0
# 52                   0.0                      0.0                  0
# 59                   0.0                      0.0                  0
# 96                   0.0                      0.0                  0
# 97                   0.0                      0.0                  0
# ..                   ...                      ...                ...
# 402                  0.0                      0.0                  0
# 403                  0.0                      0.0                  0
# 404                  0.0                      0.0                  0
# 405                  0.0                      0.0                  0
# 412                  0.0                      0.0                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 51                     0                     0               669      1347
# 52                     0                     0              1440      1347
# 59                     0                     0               426       399
# 96                     0                     0              1440      1324
# 97                     0                     0              1440      1324
# ..                   ...                   ...               ...       ...
# 402                    0                     0              1440      1429
# 403                    0                     0              1440      1429
# 404                    0                     0              1440      1429
# 405                    0                     0              1440      1429
# 412                    0                     0              1440         0
#
# [61 rows x 15 columns]

# %% [markdown]
# # 10 . who is the thired most active person in this dataset find out those in pandas and in sql both

# %% [markdown]
# ## In sql

# %% [raw]
# use pandastask3;
# select Id, sum(Calories)
# from fitbit_data
# group by Id
# order by Calories DESC
# limit 2 , 1

# %% [markdown]
# ## In pandas

# %%
df.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    3/25/2016       11004           7.11             7.11
# 1  1503960366    3/26/2016       17609          11.55            11.55
# 2  1503960366    3/27/2016       12736           8.53             8.53
# 3  1503960366    3/28/2016       13231           8.93             8.93
# 4  1503960366    3/29/2016       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                 4.07                      0.0                 33
# 1                 3.91                      0.0                 89
# 2                 3.71                      0.0                 56
# 3                 4.95                      0.0                 39
# 4                 4.61                      0.0                 28
#
#    FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 0                   12                   205               804      1819
# 1                   17                   274               588      2154
# 2                    5                   268               605      1944
# 3                   20                   224              1080      1932
# 4                   28                   243               763      1886

# %%
df.groupby(df["Id"])[["Calories"]].sum().sort_values("Calories" , ascending = False).iloc[3]
# Out:
# Calories    41414
# Name: 8877689391, dtype: int64

# %% [markdown]
# # 11 . who is the 5th most laziest person avilable in dataset find it out

# %% [markdown]
# ## In sql

# %% [raw]
# use pandastask3;
# select Id, sum(Calories)
# from fitbit_data
# group by Id
# order by Calories
# limit 5 , 1

# %% [markdown]
# ## In pandas

# %%
df.groupby(df["Id"])[["Calories"]].sum().sort_values("Calories" , ascending = True).iloc[5]
# Out:
# Calories    18187
# Name: 2891001357, dtype: int64

# %% [markdown]
# # 12 . what is a totla acumulative calories burn for a person find out

# %% [markdown]
# ## In sql

# %% [raw]
# use pandastask3;
# select Id, sum(Calories)
# from fitbit_data
# group by Id

# %% [markdown]
# ## In pandas

# %%
df.groupby(df["Id"])[["Calories"]].sum()
# Out:
#             Calories
# Id
# 1503960366     34128
# 1624580081     25705
# 1644430081     29164
# 1844505072     19391
# 1927972279     27048
# 2022484408     29704
# 2026352035     16266
# 2320127002     18385
# 2347167796     30320
# 2873212765     20349
# 2891001357     18187
# 3372868164     18603
# 3977333714     16777
# 4020332650     98412
# 4057192912     60913
# 4319703577     23931
# 4388161847     14442
# 4445114986     31617
# 4558609924     21962
# 4702921684     42322
# 5553957443     21630
# 5577150313     36303
# 6117666160     20993
# 6290855005     21656
# 6391747486     15868
# 6775888955     24523
# 6962181067     29249
# 7007744171     31525
# 7086361926     26124
# 8053475328     31825
# 8253242879     17556
# 8378563200     40274
# 8583815059     19130
# 8792009665     24884
# 8877689391     41414

# %% [markdown]
# # TASK 2

# %% [markdown]
# # 1 . load this data in sql and in pandas with a relation in sql

# %%
import pandas as pd
sheet1 = pd.read_excel(r"D:\ineuron resourses\panda task 3\Superstore_USA.xlsx", sheet_name = "Orders")
sheet2 = pd.read_excel(r"D:\ineuron resourses\panda task 3\Superstore_USA.xlsx", sheet_name = "Returns")
sheet3 = pd.read_excel(r"D:\ineuron resourses\panda task 3\Superstore_USA.xlsx", sheet_name = "Users")

# %% [markdown]
# ## import in sql

# %%
import mysql.connector as connection
mydb = connection.connect(host = "localhost",
                          user = "root",
                          passwd = "45515771",
                          use_pure = "True"
                         )
cursor = mydb.cursor()

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine("mysql+mysqlconnector://root:45515771@localhost:3306/pandastask3")

# %%
sheet1.to_sql(name = "Orders", con = engine, if_exists = "append", index = False )
# Out:
# C:\Users\sumit\anaconda3\lib\site-packages\pandas\io\sql.py:1685: UserWarning: The provided table name 'Orders' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   warnings.warn(msg, UserWarning)

# %%
sheet2.to_sql(name = "Returns", con = engine, if_exists = "append", index = False )
# Out:
# C:\Users\sumit\anaconda3\lib\site-packages\pandas\io\sql.py:1685: UserWarning: The provided table name 'Returns' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   warnings.warn(msg, UserWarning)

# %%
sheet3.to_sql(name = "Users", con = engine, if_exists = "append", index = False )
# Out:
# C:\Users\sumit\anaconda3\lib\site-packages\pandas\io\sql.py:1685: UserWarning: The provided table name 'Users' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # 3 . Find out how return that we ahve recived and with a product id

# %% [markdown]
# ## In sql

# %% [raw]
# use pandastask3;
# select o.Order_ID, o.Product_Name , r.Status, count(r.Status) as coun
# from orders o
# join returns r
#   on o.Order_ID = r.Order_ID
# group by Product_Name
# order by coun desc

# %% [markdown]
# ## In pandas

# %%
df = pd.merge(sheet1,sheet2, how = "inner", on = "Order ID")
df.groupby(df["Product Name"])[["Status"]].count()
# Out:
#                                                     Status
# Product Name
# #10 White Business Envelopes,4 1/8 x 9 1/2               1
# 12 Colored Short Pencils                                 1
# 232                                                      1
# 600 Series Flip                                          1
# 6160                                                     1
# ...                                                    ...
# Xerox 197                                                2
# Xerox 1980                                               1
# Xerox 1983                                               2
# Xerox 210                                                1
# Zoom V.92 V.44 PCI Internal Controllerless FaxM...       1
#
# [94 rows x 1 columns]

# %%
#pd.merge(df5,df6 , how ='left' , on = 'emp_id')
#pd.merge(df7,df8, how = 'inner', left_on="emp_id1", right_on="emp_id2")
#pd.merge(df9,df10 , on = ['emp_id' , 'salary'])
#df11.join(df12)

# %% [markdown]
# # 5 . Try to find out how many unique customer that we have

# %% [markdown]
# ## In sql

# %% [raw]
# use pandastask3;
# select count(distinct Customer_ID)
# from orders

# %% [markdown]
# ## In pandas

# %%
len(pd.unique(sheet1['Customer ID']))
# Out:
# 2703

# %%
sheet1.nunique(axis=0)
# Out:
# Row ID                  9426
# Order Priority             6
# Discount                  16
# Unit Price               751
# Shipping Cost            652
# Customer ID             2703
# Customer Name           2703
# Ship Mode                  3
# Customer Segment           4
# Product Category           3
# Product Sub-Category      17
# Product Container          7
# Product Name            1263
# Product Base Margin       51
# Region                     4
# State or Province         49
# City                    1424
# Postal Code             1697
# Order Date              1419
# Ship Date               1450
# Profit                  8984
# Quantity ordered new     112
# Sales                   8674
# Order ID                6455
# dtype: int64

# %% [markdown]
# # 6 . try to find out in how many regions we are selling a product and who is a manager for a respective region

# %% [markdown]
# ## In sql

# %% [raw]
# use pandastask3;
# select o.Region, State_or_Province, City, Sales, Shipping_Cost, Order_ID, u.Manager
# from orders o
# join users u
#    on o.Region = u.Region

# %% [markdown]
# ## In pandas

# %%
pd.merge(sheet1,sheet3, how="inner", on="Region")[["Region","State or Province","Order ID","Manager"]]
# Out:
#        Region State or Province  Order ID Manager
# 0     Central          Illinois     88525   Chris
# 1     Central         Minnesota     86838   Chris
# 2     Central         Minnesota     86838   Chris
# 3     Central         Minnesota     86838   Chris
# 4     Central         Minnesota     86838   Chris
# ...       ...               ...       ...     ...
# 9421    South           Georgia     88850     Sam
# 9422    South           Georgia     88842     Sam
# 9423    South           Georgia     88842     Sam
# 9424    South           Georgia     88842     Sam
# 9425    South           Georgia     88849     Sam
#
# [9426 rows x 4 columns]

# %% [markdown]
# # 7 . find out how many different differnet shipement mode that we have and what is a percentage usablity of all the shipment mode with respect to dataset

# %% [markdown]
# ## In sql

# %% [raw]
# use pandastask3;
# select Ship_Mode, sum(Shipping_Cost), sum(Profit) as total_profit
# from orders
# group by Ship_Mode
# order by total_profit desc

# %% [markdown]
# ## in pandas

# %%
sheet1.groupby(["Ship Mode"])[["Profit"]].sum().sort_values("Profit" , ascending = False)
# Out:
#                        Profit
# Ship Mode
# Regular Air     893602.126367
# Delivery Truck  268061.908387
# Express Air     150778.364674

# %% [markdown]
# # 8 . Create a new coulmn and try to find our a diffrence between order date and shipment date

# %% [markdown]
# ## In sql

# %% [raw]
# #create column
#
# use pandastask3;
# ALTER TABLE orders
# ADD datediff varchar(50)
#
#
#
# #Update values
#
# use pandastask3;
# update orders
# set datediff = datediff(Ship_Date , Order_Date)
#
#
#
# #drop column
#
# use pandastask3;
# ALTER TABLE orders
# DROP column datediff

# %% [markdown]
# ## In pandas

# %%
import numpy as np
import datetime

sheet1['Number_of_days'] = ((sheet1["Ship Date"] - sheet1["Order Date"])/np.timedelta64(1, 'D'))
sheet1['Number_of_days'] = sheet1['Number_of_days'].astype(int)

# %%
sheet1.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#   State or Province       City Postal Code  Order Date  Ship Date    Profit  \
# 0          Illinois    Addison       60101  2012-05-28 2012-05-30    1.3200
# 1        Washington  Anacortes       98221  2010-07-07 2010-07-08    4.5600
# 2        Washington  Anacortes       98221  2011-07-27 2011-07-28  -47.6400
# 3        Washington  Anacortes       98221  2011-07-27 2011-07-28  -30.5100
# 4        Washington  Anacortes       98221  2011-07-27 2011-07-27  998.2023
#
#   Quantity ordered new    Sales Order ID Number_of_days
# 0                    2     5.90    88525              2
# 1                    4    13.01    88522              1
# 2                    7    49.92    88523              1
# 3                    7    41.64    88523              1
# 4                    8  1446.67    88523              0
#
# [5 rows x 25 columns]

# %%
sheet1.dtypes
# Out:
# Row ID                           int64
# Order Priority                  object
# Discount                       float64
# Unit Price                     float64
# Shipping Cost                  float64
# Customer ID                      int64
# Customer Name                   object
# Ship Mode                       object
# Customer Segment                object
# Product Category                object
# Product Sub-Category            object
# Product Container               object
# Product Name                    object
# Product Base Margin            float64
# Region                          object
# State or Province               object
# City                            object
# Postal Code                      int64
# Order Date              datetime64[ns]
# Ship Date               datetime64[ns]
# Profit                         float64
# Quantity ordered new             int64
# Sales                          float64
# Order ID                         int64
# Number_of_days                   int32
# dtype: object

# %% [markdown]
# # 9 . base on question number 8 find out for which order id we have shipment duration more than 10 days

# %% [markdown]
# ## In sql

# %% [raw]
# use pandastask3;
# select *
# from orders
# where datediff > 10
# order by datediff

# %% [markdown]
# ## In pandas

# %%
sheet1[sheet1["Number_of_days"]>10]
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 643    18246       Critical      0.05       11.09           5.25          250
# 1548   23091         Medium      0.04      100.98           7.18          595
# 1549   23092         Medium      0.09        6.48           7.49          595
# 1678   20703  Not Specified      0.07      130.98          30.00          637
# 1679   20704  Not Specified      0.09       55.98           4.86          637
# 1680   20705  Not Specified      0.08      115.99           4.23          637
# 1697    2703  Not Specified      0.07      130.98          30.00          640
# 1698    2704  Not Specified      0.09       55.98           4.86          640
# 1699    2705  Not Specified      0.08      115.99           4.23          640
# 2515   18060            Low      0.02        2.21           1.00          964
# 5548   21603  Not Specified      0.02        5.58           1.99         2048
# 5673   19005            Low      0.06       65.99           2.50         2088
# 5859   24392            Low      0.05       29.89           1.99         2143
# 5881   21257            Low      0.05        7.99           5.03         2153
# 8607   26351         Medium      0.00        8.32           2.38         3119
# 8609   26350         Medium      0.07      180.98          55.24         3119
# 8610   26352         Medium      0.06        4.20           2.26         3119
# 8973   20750            Low      0.06      125.99           8.08         3248
# 8982    2748            Low      0.03       11.97           5.81         3251
# 8983    2749            Low      0.08      195.99           4.20         3251
# 8993    2750            Low      0.06      125.99           8.08         3251
# 8996   20748            Low      0.03       11.97           5.81         3252
# 8997   20749            Low      0.08      195.99           4.20         3252
#
#                 Customer Name       Ship Mode Customer Segment  \
# 643   Brenda Nelson Blanchard     Regular Air        Corporate
# 1548               Dana Desai     Regular Air   Small Business
# 1549               Dana Desai     Express Air   Small Business
# 1678       Christopher Bryant  Delivery Truck         Consumer
# 1679       Christopher Bryant     Regular Air         Consumer
# 1680       Christopher Bryant     Regular Air         Consumer
# 1697               Neal Wolfe  Delivery Truck         Consumer
# 1698               Neal Wolfe     Regular Air         Consumer
# 1699               Neal Wolfe     Regular Air         Consumer
# 2515          Virginia Rivera     Regular Air      Home Office
# 5548          Ricky Dougherty     Regular Air         Consumer
# 5673             Carrie Boyle     Regular Air        Corporate
# 5859            Lester Sawyer     Regular Air      Home Office
# 5881               Anna Glenn     Regular Air      Home Office
# 8607              Jay Hubbard     Express Air        Corporate
# 8609              Jay Hubbard  Delivery Truck        Corporate
# 8610              Jay Hubbard     Regular Air        Corporate
# 8973            Earl Donnelly     Express Air        Corporate
# 8982             Peter Brooks     Regular Air        Corporate
# 8983             Peter Brooks     Regular Air        Corporate
# 8993             Peter Brooks     Express Air        Corporate
# 8996           Milton Harrell     Regular Air        Corporate
# 8997           Milton Harrell     Regular Air        Corporate
#
#      Product Category  ... State or Province           City Postal Code  \
# 643   Office Supplies  ...         Minnesota      Richfield       55423
# 1548       Technology  ...           Indiana    Bloomington       47401
# 1549  Office Supplies  ...           Indiana    Bloomington       47401
# 1678        Furniture  ...        California    Santa Clara       95051
# 1679  Office Supplies  ...        California    Santa Clara       95051
# 1680       Technology  ...        California    Santa Clara       95051
# 1697        Furniture  ...        Washington        Seattle       98119
# 1698  Office Supplies  ...        Washington        Seattle       98119
# 1699       Technology  ...        Washington        Seattle       98119
# 2515  Office Supplies  ...        California   Redwood City       94061
# 5548  Office Supplies  ...      South Dakota      Brookings       57006
# 5673       Technology  ...          New York   Mount Vernon       10550
# 5859       Technology  ...          Virginia        Fairfax       20151
# 5881       Technology  ...        California       Pasadena       91104
# 8607       Technology  ...           Florida        Orlando       32839
# 8609  Office Supplies  ...           Florida        Orlando       32839
# 8610  Office Supplies  ...           Florida        Orlando       32839
# 8973       Technology  ...         Louisiana        Slidell       70458
# 8982  Office Supplies  ...          New York  New York City       10112
# 8983       Technology  ...          New York  New York City       10112
# 8993       Technology  ...          New York  New York City       10112
# 8996  Office Supplies  ...          New York      Rotterdam       12306
# 8997       Technology  ...          New York      Rotterdam       12306
#
#       Order Date  Ship Date     Profit Quantity ordered new     Sales  \
# 643   2011-12-29 2012-03-22    58.5000                   19    204.67
# 1548  2011-12-30 2012-01-10   375.7050                    6    587.46
# 1549  2011-12-30 2012-01-14   -47.3950                   12     79.37
# 1678  2011-12-30 2012-01-16  -211.8850                   21   2699.94
# 1679  2011-12-30 2012-01-10   355.0119                   10    514.51
# 1680  2011-12-30 2012-01-27  1021.4001                   16   1480.29
# 1697  2011-12-30 2012-01-16  -423.7700                   83  10671.20
# 1698  2011-12-30 2012-01-10   469.6900                   41   2109.51
# 1699  2011-12-30 2012-01-27   727.3620                   65   6013.69
# 2515  2011-12-30 2012-03-31     5.8200                   10     22.35
# 5548  2011-12-30 2012-01-13    66.2250                   21    121.51
# 5673  2011-12-28 2012-01-14   187.4880                    8    451.34
# 5859  2011-12-26 2012-01-17  4230.2001                   12    344.16
# 5881  2011-12-26 2012-01-19   -23.4520                    2     15.56
# 8607  2011-12-29 2012-01-16 -1075.3960                   19    170.62
# 8609  2013-12-29 2014-01-15  -147.5180                   25   4529.95
# 8610  2013-12-29 2014-01-17  -689.8738                    2      9.64
# 8973  2011-12-26 2012-01-14     2.4780                   20   2180.31
# 8982  2011-12-26 2012-01-22   -31.7400                   31    388.52
# 8983  2011-12-26 2012-01-26  -557.9530                   13   2092.05
# 8993  2013-12-26 2014-01-14  1304.5590                   86   9375.35
# 8996  2011-12-26 2012-01-22   -15.8700                    8    100.26
# 8997  2011-12-26 2012-01-26  -278.9765                    3    482.78
#
#      Order ID Number_of_days
# 643     87215             84
# 1548    86318             11
# 1549    86318             15
# 1678    87957             17
# 1679    87957             11
# 1680    87957             28
# 1697    19556             17
# 1698    19556             11
# 1699    19556             28
# 2515    86177             92
# 5548    88223             14
# 5673    88352             17
# 5859    87572             22
# 5881    91294             24
# 8607    86434             18
# 8609    86436             17
# 8610    86436             19
# 8973    87300             19
# 8982    19841             27
# 8983    19841             31
# 8993    19841             19
# 8996    87300             27
# 8997    87300             31
#
# [23 rows x 25 columns]

# %% [markdown]
# # 10 . Try to find out a list of a returned order which sihpment duration was more then 15 days and find out that region manager as well

# %% [markdown]
# ## In sql

# %% [raw]
# use pandastask3;
# select o.Order_ID , r.Status, u.Region, u.Manager, o.datediff
# from orders o
# join returns r
#   on o.Order_ID = r.Order_ID
# left join users u
#   on o.Region = u.Region
# having datediff > 5

# %% [markdown]
# ## In pandas

# %%
df = pd.merge(pd.merge(sheet1,sheet2, how = "inner", on = "Order ID"),sheet3, how = "left", on = "Region")
df[df["Number_of_days"]>5][["Order ID","Status","Region","Manager","Number_of_days"]]
# Out:
#     Order ID    Status Region  Manager  Number_of_days
# 25     51559  Returned   West  William               9
# 43     41760  Returned   East     Erin               7
# 88     32931  Returned   West  William               7

# %% [markdown]
# # 11 . Group by region and find out which region is more profitable

# %% [markdown]
# ## In sql

# %% [raw]
# use pandastask3;
# select o.Order_ID, u.Region, avg(o.Profit) as Totalprofit
# from orders o
# join users u
#   on o.Region = u.Region
# group by u.Region
# order by o.Profit DESC

# %% [markdown]
# ## In pandas

# %%
df= pd.merge(sheet1,sheet3, how = "left", on = "Region")
df.groupby(df['Region'])[['Profit']].mean().sort_values('Profit' , ascending = False)
# Out:
#              Profit
# Region
# Central  179.312027
# East     164.948094
# West     136.098710
# South     53.327120

# %% [markdown]
# # 12 . Try to find out overalll in which country we are giving more didscount

# %% [markdown]
# ## In sql

# %% [raw]
# use pandastask3;
# select o.Order_ID, o.State_or_Province, avg(o.Discount) as total_disc
# from orders o
# group by o.State_or_Province
# order by total_disc DESC
# limit 1

# %% [markdown]
# ## In pandas

# %%
sheet1.groupby(sheet1["State or Province"])[["Discount"]].mean().sort_values("Discount" , ascending = False).iloc[0]
# Out:
# Discount    0.054762
# Name: Wyoming, dtype: float64

# %% [markdown]
# # 13 . Give me a list of unique postal code

# %% [markdown]
# ## In sql

# %% [raw]
# use pandastask3;
# select Postalcode
# from orders
# group by Postalcode

# %% [markdown]
# ## In pandas

# %%
len(pd.unique(sheet1["Postal Code"]))
# Out:
# 1697

# %%
sheet1.nunique(axis=0)
# Out:
# Row ID                  9426
# Order Priority             6
# Discount                  16
# Unit Price               751
# Shipping Cost            652
# Customer ID             2703
# Customer Name           2703
# Ship Mode                  3
# Customer Segment           4
# Product Category           3
# Product Sub-Category      17
# Product Container          7
# Product Name            1263
# Product Base Margin       51
# Region                     4
# State or Province         49
# City                    1424
# Postal Code             1697
# Order Date              1419
# Ship Date               1450
# Profit                  8984
# Quantity ordered new     112
# Sales                   8674
# Order ID                6455
# Number_of_days            23
# dtype: int64

# %% [markdown]
# # 14 . which customer segement is more profitalble find it out .

# %% [markdown]
# ## In sql

# %% [raw]
# use pandastask3;
# select Customer_Segment , avg(Profit)
# from orders
# group by Customer_Segment

# %% [markdown]
# ## in pandas

# %%
sheet1.groupby(sheet1["Customer Segment"])[["Profit"]].mean().sort_values("Profit" , ascending = False)
# Out:
#                       Profit
# Customer Segment
# Small Business    171.903635
# Corporate         149.789223
# Home Office       122.568892
# Consumer          109.059992

# %% [markdown]
# # 15 . try to find out the 10th most loss making product catagory .

# %% [markdown]
# ## In sql

# %% [raw]
# use pandastask3;
# select Product_Category , avg(Profit) as profit
# from orders
# group by Product_Category
# order by profit DESC
# limit 1

# %% [markdown]
# ## In pandas

# %%
sheet1.groupby(sheet1["Product Category"])[["Profit"]].mean().sort_values("Profit" , ascending = False)
# Out:
#                       Profit
# Product Category
# Technology        295.457563
# Furniture          91.750801
# Office Supplies    87.239957

# %% [markdown]
# # 16 . Try to find out 10 top  product with highest margins

# %% [markdown]
# ## In sql

# %% [raw]
# use pandastask3;
# select Product_Name , Product_Base_Margin
# from orders
# group by Product_Name
# order by Product_Base_Margin DESC
# limit 10

# %% [markdown]
# ## in pandas

# %%
sheet1[["Product Name" , "Product Base Margin"]].sort_values("Product Base Margin" , ascending = False).iloc[0:10]
# Out:
#                                            Product Name  Product Base Margin
# 9145                                        Accessory27                 0.85
# 4756                                         Accessory4                 0.85
# 7607                                        Accessory27                 0.85
# 5672                                         Accessory4                 0.85
# 4168                  Sterling Rubber Bands by Alliance                 0.85
# 807                                         Accessory27                 0.85
# 816                                         Accessory27                 0.85
# 3994  Office Impressions Heavy Duty Welded Shelving ...                 0.85
# 2138                  Sterling Rubber Bands by Alliance                 0.85
# 7202  Office Impressions Heavy Duty Welded Shelving ...                 0.85
